# %%
import numpy as np

data = np.load("C:/Users/aaran/Downloads/Datasets/RNN/Traffic/PEMS04/PEMS04.npz")
print(data.files)   # te muestra las claves disponibles
X = data['data']    # matriz de tráfico: [tiempo, sensores, features]
print(X.shape)      # (16992, 307, 3) por ejemplo
# Out:
# ['data']
# (16992, 307, 3)

# %%
import numpy as np

data = np.load("C:/Users/aaran/Downloads/Datasets/RNN/Traffic/PEMS08/PEMS08.npz")
print(data.files)   # te muestra las claves disponibles
X = data['data']    # matriz de tráfico: [tiempo, sensores, features]
print(X.shape)      # (16992, 307, 3) por ejemplo
# Out:
# ['data']
# (17856, 170, 3)

# %%
import h5py
f = h5py.File('C:/Users/aaran/Downloads/Datasets/RNN/Traffic/PEMS_BAY/pems-bay.h5', 'r')
print(list(f.keys()))
# Ejemplo: ['speed']
# data = f['speed'][:]
# print(data.shape)
# # Ejemplo: (325, 52116)
# Out:
# ['speed']
